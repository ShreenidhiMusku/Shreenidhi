# %%
student = {
    "name"  : "Shreenidhi",
    "age"   : 18,
    "grade" : "A",
    "score" : 94.5
}
print(student)
print(student["name"])
print(student["score"])
# Out:
# {'name': 'Shreenidhi', 'age': 18, 'grade': 'A', 'score': 94.5}
# Shreenidhi
# 94.5

# %%
constants = {
    'pi'         : 3.14159265,
    'e'          : 2.71828182,
    'phi'        : 1.61803398,
    'sqrt2'      : 1.41421356,
}

print(constants['pi'])
print(constants['e'])
print(constants['phi'])
print(constants['sqrt2'])
# Out:
# 3.14159265
# 2.71828182
# 1.61803398
# 1.41421356

# %%
marks = {'Math': 88, 'Physics': 78, 'Chemistry': 85}

marks['Biology'] = 92
marks['Math']    = 97
del marks['Chemistry']
print('Updated marks:', marks)
for subject, score in marks.items():
    print(f'  {subject:7s}: {score}')
# Out:
# Updated marks: {'Math': 97, 'Physics': 78, 'Biology': 92}
#   Math   : 97
#   Physics: 78
#   Biology: 92

# %%
A = {1, 2, 3, 4, 5}
B = {3, 4, 5, 6, 7}
print('A           :', A)
print('B           :', B)
print('Union A|B   :', A | B)
print('Intersection:', A & B)
print('Difference  :', A - B)
print('Symmetric   :', A ^ B)
# Out:
# A           : {1, 2, 3, 4, 5}
# B           : {3, 4, 5, 6, 7}
# Union A|B   : {1, 2, 3, 4, 5, 6, 7}
# Intersection: {3, 4, 5}
# Difference  : {1, 2}
# Symmetric   : {1, 2, 6, 7}

# %%
numbers_with_duplicates = [1, 2, 2, 3, 3, 3, 4, 5, 5]
unique_numbers = set(numbers_with_duplicates)

print('Original :', numbers_with_duplicates)
print('Unique   :', unique_numbers)
# Out:
# Original : [1, 2, 2, 3, 3, 3, 4, 5, 5]
# Unique   : {1, 2, 3, 4, 5}

# %%
number = -12
if number > 0:
    print('Positive number')
elif number == 0:
    print('Number is zero')
else:
    print('Negative number')
# Out:
# Negative number

# %%
def f(x):
    if x >= 0:
        return x ** 2
    else:
        return -x
for val in [-3, -1, 0, 2, 5]:
    print(f'f({val:2d}) = {f(val)}')
# Out:
# f(-3) = 3
# f(-1) = 1
# f( 0) = 0
# f( 2) = 4
# f( 5) = 25

# %%
score = 85

if score >= 90:
    grade = 'A (Excellent)'
elif score >= 80:
    grade = 'B (Good)'
elif score >= 70:
    grade = 'C (Average)'
elif score >= 60:
    grade = 'D (Below Average)'
else:
    grade = 'F (Fail)'

print(f'Score: {score} → Grade: {grade}')
# Out:
# Score: 85 → Grade: B (Good)

# %%
x = 18
if x > 10 and x < 20:
    print(f'{x} is between 10 and 20')
if x < 5 or x > 12:
    print(f'{x} is outside the range 5–12')
if not x == 10:
    print(f'{x} is not equal to 10')
# Out:
# 18 is between 10 and 20
# 18 is outside the range 5–12
# 18 is not equal to 10

# %%
n = 45
if n % 2 == 0:
    print(f'{n} is Even')
else:
    print(f'{n} is Odd')

if n % 3 == 0 and n % 5 == 0:
    print(f'{n} is divisible by both 3 and 5')
elif n % 3 == 0:
    print(f'{n} is divisible by 3 only')
elif n % 5 == 0:
    print(f'{n} is divisible by 5 only')
# Out:
# 45 is Odd
# 45 is divisible by both 3 and 5

# %%
print('Counting from 1 to 6:')
for i in range(1, 7):
    print(i)
# Out:
# Counting from 1 to 6:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
n = 5
total = 0
for i in range(1, n + 1):
    total += i
formula_result = n * (n + 1) // 2
print(f'Sum (loop)    : {total}')
print(f'Sum (formula) : {formula_result}')
# Out:
# Sum (loop)    : 15
# Sum (formula) : 15

# %%
n = 6
factorial = 1
for i in range(1, n + 1):
    factorial *= i
    print(f'  {i}! = {factorial}')
print(f'\n6! = {factorial}')
# Out:
#   1! = 1
#   2! = 2
#   3! = 6
#   4! = 24
#   5! = 120
#   6! = 720
#
# 6! = 720

# %%
import os
print("Current Directory:", os.getcwd())
print("Files and Folders:", os.listdir())
os.mkdir("demo_folder")
os.rename("demo_folder", "renamed_folder")
os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']

# %%
from datetime import datetime, date, timedelta
now = datetime.now()
print("Now:", now)
today = date.today()
print("Today's Date:", today)
dob = date(2008, 3, 22)
print("DOB:", dob)
yesterday = today - timedelta(days=1)
tomorrow = today + timedelta(days=1)
print("Yesterday:", yesterday)
print("Tomorrow:", tomorrow)
formatted = now.strftime("%d-%m-%Y %H:%M:%S")
print("Formatted DateTime:", formatted)
# Out:
# Now: 2026-07-17 09:23:01.482801
# Today's Date: 2026-07-17
# DOB: 2008-03-22
# Yesterday: 2026-07-16
# Tomorrow: 2026-07-18
# Formatted DateTime: 17-07-2026 09:23:01

# %%
import random
print("Random Int:", random.randint(1, 100))
print("Random Float:", random.random())
colors = ['red', 'green', 'blue']
print("Random Color:", random.choice(colors))
random.shuffle(colors)
print("Shuffled List:", colors)
print("Sample:", random.sample(range(1, 50), 5))
# Out:
# Random Int: 6
# Random Float: 0.6834804940124393
# Random Color: green
# Shuffled List: ['green', 'red', 'blue']
# Sample: [26, 33, 20, 22, 40]

# %%
from collections import Counter
fruits = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple', 'apple']
count = Counter(fruits)
print("Fruit Count:", count)
# Out:
# Fruit Count: Counter({'apple': 4, 'banana': 2, 'orange': 1})

# %%
from collections import defaultdict
marks = defaultdict(lambda: 0)
marks['Math'] = 90
marks['Science'] = 80
print("English Marks (not set):", marks['English'])
# Out:
# English Marks (not set): 0

# %%
from collections import namedtuple
Point = namedtuple('Point', 'x y')
p1 = Point(10, 20)
print("Point:", p1)
print("x:", p1.x, "y:", p1.y)
# Out:
# Point: Point(x=10, y=20)
# x: 10 y: 20

# %%
from collections import deque
dq = deque([1, 2, 3])
dq.append(4)
dq.append(5)
dq.pop()
dq.appendleft(0)
dq.popleft()
print("Deque after operations:", dq)
# Out:
# Deque after operations: deque([1, 2, 3, 4])

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

raw_sensor_data = []
base_timestamp = datetime.datetime(2023, 1, 1, 9, 0, 0) # Starting timestamp

for i in range(1, 101):
    timestamp = base_timestamp + datetime.timedelta(minutes=i
    timestamp_str = timestamp.strftime('%Y-%m-%d %H:%M:%S')

    device_id = f'DEV{i:03d}'
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    raw_sensor_data.append((timestamp_str, device_id, device_type, location, value))

print(f"Generated {len(raw_sensor_data)} raw sensor readings.")
print("First 5 readings:")
for reading in raw_sensor_data[:5]:
    print(reading)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# Generated 100 raw sensor readings.
# First 5 readings:
# ('2023-01-01 09:01:00', 'DEV001', 'Light_Sensor', 'Warehouse', 627.78)
# ('2023-01-01 09:02:00', 'DEV002', 'Temperature_Sensor', 'OfficeA', 24.08)
# ('2023-01-01 09:03:00', 'DEV003', 'Humidity_Sensor', 'Lab2', 79.61)
# ('2023-01-01 09:04:00', 'DEV004', 'Pressure_Sensor', 'OfficeA', 1019.52)
# ('2023-01-01 09:05:00', 'DEV005', 'Light_Sensor', 'Warehouse', 630.36)

# %% [markdown]
# ### 1.2 Basic List Operations: Indexing and Slicing
#
# Let's explore the generated `raw_sensor_data` list using indexing and slicing to access specific readings or subsets of data.

# %%
# Access the first reading
first_reading = raw_sensor_data[0]
print(f"First Reading: {first_reading}")

# Access the last reading
last_reading = raw_sensor_data[-1]
print(f"Last Reading: {last_reading}")

# Access a slice of readings (e.g., readings from index 5 to 9)
slice_of_readings = raw_sensor_data[5:10]
print("\nReadings from index 5 to 9:")
for reading in slice_of_readings:
    print(reading)

# %%
import os

# Get current working directory
print("Current Directory:", os.getcwd())

# List files and directories in current directory
print("Files and Folders:", os.listdir())

# Create a new folder
os.mkdir("demo_folder")  # Creates folder named 'demo_folder'

# Rename a folder
os.rename("demo_folder", "renamed_folder")

# Remove a folder (make sure it's empty)
os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")
raw_sensor_data = []

for i in range(1, 101):
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    timestamp = (
        datetime.datetime.now() -
        datetime.timedelta(minutes=random.randint(0, 1000))
    ).strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i:03d}"

    reading = (timestamp, device_id, device_type, location, value)
    raw_sensor_data.append(reading)

print("Total Sensor Readings:", len(raw_sensor_data))
print("First Reading:", raw_sensor_data[0])


# ---------------- Task 1.2 ----------------
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temp_dict = {
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        }
        temperature_readings.append(temp_dict)

print("\nTemperature Readings:", len(temperature_readings))


# ---------------- Task 1.3 ----------------
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print("\nUnique Locations:")
print(unique_locations)


# ---------------- Task 1.4 ----------------
device_stats = {}

# Initialize dictionary
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

# Find min and max
for reading in raw_sensor_data:
    device = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device]

    if value < current_min:
        current_min = value

    if value > current_max:
        current_max = value

    device_stats[device] = (current_min, current_max)

print("\nDevice Statistics:")
for device, stats in device_stats.items():
    print(device, "-> Min:", stats[0], "Max:", stats[1])


# ---------------- Task 1.5.1 ----------------
# Elements from 10th to 20th (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Every 5th reading
sliced_readings_2 = raw_sensor_data[::5]

print("\n10th to 20th Readings:", len(sliced_readings_1))
print("Every 5th Reading:", len(sliced_readings_2))


# ---------------- Task 1.5.2 ----------------
sample_string = "PythonProgrammingIsFun"

# Extract "Programming"
substring_1 = sample_string[6:17]

# Reverse of "Python"
substring_2 = sample_string[5::-1]

print("\nSubstring 1:", substring_1)
print("Substring 2:", substring_2)


# ---------------- Task 1.5.3 ----------------
# Device type of 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

print("\n5th Reading Device Type:", fifth_reading_device_type)
print("Suffix:", device_type_suffix)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# Total Sensor Readings: 100
# First Reading: ('2026-07-30 22:31:28', 'DEV001', 'Humidity_Sensor', 'Lab2', 33.74)
#
# Temperature Readings: 24
#
# Unique Locations:
# {'Lab1', 'Warehouse', 'OfficeB', 'OfficeA', 'Lab2'}
#
# Device Statistics:
# Temperature_Sensor -> Min: 18.26 Max: 29.77
# Humidity_Sensor -> Min: 30.88 Max: 79.24
# Pressure_Sensor -> Min: 980.46 Max: 1029.64
# Light_Sensor -> Min: 153.32 Max: 981.85
#
# 10th to 20th Readings: 11
# Every 5th Reading: 20
#
# Substring 1: Programming
# Substring 2: nohtyP
#
# 5th Reading Device Type: Light_Sensor
# Suffix: Sensor
